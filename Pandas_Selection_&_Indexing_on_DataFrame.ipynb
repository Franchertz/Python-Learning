# %% [markdown]
# <a href="https://colab.research.google.com/github/Franchertz/Python-Learning/blob/main/Pandas_Selection_%26_Indexing_on_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
np.random.randn(10,5)
# Out:
# array([[ 0.51682576,  1.08746072,  0.51326278, -0.4878641 , -0.13977587],
#        [-0.71379175, -0.13761533,  0.24382519, -0.13463908,  1.09714209],
#        [ 0.35060383,  1.42655583, -0.27463826, -0.33864947, -0.47955883],
#        [ 0.96599381, -0.18558468,  0.5262232 ,  0.70081037,  1.47289789],
#        [-0.25077008, -1.43556647,  1.11116209,  1.35103314, -0.268639  ],
#        [-1.054374  ,  0.47492884, -0.31060089, -0.26568263, -0.84183961],
#        [ 0.06884777, -0.43527753, -1.04614244, -0.49988755,  0.40160555],
#        [ 1.36059141, -0.34930401, -0.04646366,  1.47448701, -1.00317386],
#        [ 0.26924831, -0.52809464, -1.54541814, -1.58237439,  1.16478915],
#        [ 0.49610764, -0.00660568, -0.20821323, -0.10624038, -0.17225927]])

# %%
my_dataframe = pd.DataFrame(np.random.randn(10,5), index='row1 row2 row3 row4 row5 row6 row7 row8 row9 row10'.split(),
                            columns='column1 column2 column3 column4 column5'.split())

# %%
my_dataframe
# Out:
#         column1   column2   column3   column4   column5
# row1   1.075885  0.445189  0.023743 -1.451339  0.684811
# row2  -0.379217 -1.752118  0.539353 -0.376163 -1.777010
# row3  -1.114152 -0.684932  0.045150  1.300284  0.937585
# row4  -0.161399  0.794863  0.950149  0.848595 -1.387862
# row5   1.097791  0.951111  0.161361  1.679532 -0.338595
# row6   1.107007 -0.928650 -2.559176  0.715428 -0.492681
# row7   0.216499 -1.117392  0.505855  0.622816 -0.156741
# row8   1.835657 -0.508881  0.988306  0.155926 -1.180818
# row9   0.763417 -0.361787 -0.152206 -0.629966 -0.701518
# row10 -0.868170  1.857782  0.712229 -1.192275 -0.910246

# %%
type(my_dataframe['column1'])
# Out:
# pandas.core.series.Series

# %%
type(my_dataframe)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Indexing & Selection**

# %%
my_dataframe['column2']  #Selecting a single column
# Out:
# row1    -0.342687
# row2     1.055895
# row3    -0.995818
# row4    -1.071852
# row5    -0.064957
# row6     0.704771
# row7    -0.234841
# row8     0.178008
# row9    -0.936510
# row10   -0.601000
# Name: column2, dtype: float64

# %%
my_dataframe[['column3', 'column5','column4']]
# Out:
#         column3   column5   column4
# row1   2.368320 -0.858996  0.922993
# row2  -0.759724  0.243360 -0.679701
# row3  -0.398095  0.918767 -0.730018
# row4  -0.960031 -1.305585 -0.665915
# row5  -0.603603  0.319060 -0.196169
# row6  -1.400559 -0.722114 -0.855394
# row7  -1.755879 -0.912259 -0.695788
# row8   2.038446  0.880109 -0.424680
# row9   0.007945  0.250329 -0.234946
# row10  0.874962 -0.880276  2.110079

# %% [markdown]
# **Reading DataSet Into DataFrame**
#
# *Reading the Pandas documentation for more info:
#  https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html*
#
# *Dealing with csv Files:
# https://towardsdatascience.com/pandas-dataframe-playing-with-csv-files-944225d19ff*

# %%
cat Automobile.csv  #Imported and called up a csv(comma-separated values) file
# Out:
# ﻿symboling,normalized_losses,make,fuel_type,aspiration,number_of_doors,body_style,drive_wheels,engine_location,wheel_base,length,width,height,curb_weight,engine_type,number_of_cylinders,engine_size,fuel_system,bore,stroke,compression_ratio,horsepower,peak_rpm,city_mpg,highway_mpg,price
# 3,168,alfa-romero,gas,std,two,convertible,rwd,front,88.6,168.8,64.1,48.8,2548,dohc,four,130,mpfi,3.47,2.68,9,111,5000,21,27,13495
# 3,168,alfa-romero,gas,std,two,convertible,rwd,front,88.6,168.8,64.1,48.8,2548,dohc,four,130,mpfi,3.47,2.68,9,111,5000,21,27,16500
# 1,168,alfa-romero,gas,std,two,hatchback,rwd,front,94.5,171.2,65.5,52.4,2823,ohcv,six,152,mpfi,2.68,3.47,9,154,5000,19,26,16500
# 2,164,audi,gas,std,four,sedan,fwd,front,99.8,176.6,66.2,54.3,2337,ohc,four,109,mpfi,3.19,3.4,10,102,5500,24,30,13950
# 2,164,audi,gas,std,four,sedan,4wd,front,99.4,176.6,66.4,54.3,2824,ohc,five,136,mpfi,3.19,3.4,8,115,5500,18,22,17450
# ...

# %%
data_auto=pd.read_csv('Automobile.csv') #Since data is in csv format, we use read_csv to read

# %%
data_auto
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data_auto.head()  #printing the first 5 rows of the dataframe
#data_auto.head(20) can also be run and you will get the first 20 rows
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data_auto.tail() #printingthe last 5 rows using the tail function
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %% [markdown]
# **Adding a Column to DataFrame**

# %%
my_dataframe['column6']=my_dataframe['column1']*2

# %%
my_dataframe
# Out:
#         column1   column2   column3   column4   column5   column6
# row1   1.075885  0.445189  0.023743 -1.451339  0.684811  2.151770
# row2  -0.379217 -1.752118  0.539353 -0.376163 -1.777010 -0.758433
# row3  -1.114152 -0.684932  0.045150  1.300284  0.937585 -2.228304
# row4  -0.161399  0.794863  0.950149  0.848595 -1.387862 -0.322798
# row5   1.097791  0.951111  0.161361  1.679532 -0.338595  2.195582
# row6   1.107007 -0.928650 -2.559176  0.715428 -0.492681  2.214013
# row7   0.216499 -1.117392  0.505855  0.622816 -0.156741  0.432997
# row8   1.835657 -0.508881  0.988306  0.155926 -1.180818  3.671315
# row9   0.763417 -0.361787 -0.152206 -0.629966 -0.701518  1.526834
# row10 -0.868170  1.857782  0.712229 -1.192275 -0.910246 -1.736340

# %%
type(my_dataframe['column6'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Dropping Columns & Rows**

# %%
my_dataframe.drop('column4', axis=1) #axis=1 is used to refer to the columns and axix=0 refers to the rows
# Out:
#         column1   column2   column3   column5   column6
# row1   1.075885  0.445189  0.023743  0.684811  2.151770
# row2  -0.379217 -1.752118  0.539353 -1.777010 -0.758433
# row3  -1.114152 -0.684932  0.045150  0.937585 -2.228304
# row4  -0.161399  0.794863  0.950149 -1.387862 -0.322798
# row5   1.097791  0.951111  0.161361 -0.338595  2.195582
# row6   1.107007 -0.928650 -2.559176 -0.492681  2.214013
# row7   0.216499 -1.117392  0.505855 -0.156741  0.432997
# row8   1.835657 -0.508881  0.988306 -1.180818  3.671315
# row9   0.763417 -0.361787 -0.152206 -0.701518  1.526834
# row10 -0.868170  1.857782  0.712229 -0.910246 -1.736340

# %%
my_dataframe #our dataframe still has column4...why?
# Out:
#         column1   column2   column3   column4   column5   column6
# row1   1.075885  0.445189  0.023743 -1.451339  0.684811  2.151770
# row2  -0.379217 -1.752118  0.539353 -0.376163 -1.777010 -0.758433
# row3  -1.114152 -0.684932  0.045150  1.300284  0.937585 -2.228304
# row4  -0.161399  0.794863  0.950149  0.848595 -1.387862 -0.322798
# row5   1.097791  0.951111  0.161361  1.679532 -0.338595  2.195582
# row6   1.107007 -0.928650 -2.559176  0.715428 -0.492681  2.214013
# row7   0.216499 -1.117392  0.505855  0.622816 -0.156741  0.432997
# row8   1.835657 -0.508881  0.988306  0.155926 -1.180818  3.671315
# row9   0.763417 -0.361787 -0.152206 -0.629966 -0.701518  1.526834
# row10 -0.868170  1.857782  0.712229 -1.192275 -0.910246 -1.736340

# %%
my_dataframe.drop('column4', axis=1, inplace=True)  #using inplac=True to effect changes on original file

# %%
my_dataframe
# Out:
#         column1   column2   column3   column5   column6
# row1   1.075885  0.445189  0.023743  0.684811  2.151770
# row2  -0.379217 -1.752118  0.539353 -1.777010 -0.758433
# row3  -1.114152 -0.684932  0.045150  0.937585 -2.228304
# row4  -0.161399  0.794863  0.950149 -1.387862 -0.322798
# row5   1.097791  0.951111  0.161361 -0.338595  2.195582
# row6   1.107007 -0.928650 -2.559176 -0.492681  2.214013
# row7   0.216499 -1.117392  0.505855 -0.156741  0.432997
# row8   1.835657 -0.508881  0.988306 -1.180818  3.671315
# row9   0.763417 -0.361787 -0.152206 -0.701518  1.526834
# row10 -0.868170  1.857782  0.712229 -0.910246 -1.736340

# %%
my_dataframe.drop('row2', axis=0, inplace=True) #axis=0 refering to the rows

# %%
my_dataframe
# Out:
#         column1   column2   column3   column5   column6
# row1   1.075885  0.445189  0.023743  0.684811  2.151770
# row3  -1.114152 -0.684932  0.045150  0.937585 -2.228304
# row4  -0.161399  0.794863  0.950149 -1.387862 -0.322798
# row5   1.097791  0.951111  0.161361 -0.338595  2.195582
# row6   1.107007 -0.928650 -2.559176 -0.492681  2.214013
# row7   0.216499 -1.117392  0.505855 -0.156741  0.432997
# row8   1.835657 -0.508881  0.988306 -1.180818  3.671315
# row9   0.763417 -0.361787 -0.152206 -0.701518  1.526834
# row10 -0.868170  1.857782  0.712229 -0.910246 -1.736340

# %%
my_dataframe.iloc[1]
# Out:
# column1   -1.114152
# column2   -0.684932
# column3    0.045150
# column5    0.937585
# column6   -2.228304
# Name: row3, dtype: float64

# %%
my_dataframe.loc['row7','column2']
# Out:
# -1.1173918170584398
